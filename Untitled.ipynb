# %% [markdown]
# #### Plotting
# Using Bokeh it is possible to display all the plots in an interactive fashion and this library provides a simple way to generate a large number of default plots per file and also allows for plotting any combination of parameters. It is also possible to generate 'interactive' plots that allow you to use a slider to move through the start to end simulation.

# %%
from particle_distribution import processing_tools_mult_class as pt

filepath = '/home/daniel_b/Documents/Summer_project/example.h5'
FEL = pt.ProcessedData(filepath,num_slices=100,undulator_period=0.00275,k_fact=2.7)

# %% [markdown]
# The default plots are very easy to call and this can be done by passing a computed object into the plotting class. This is most easily done by using the ProcessedData class directly, as this ensures that all the necessary calculations will have been done. This is not necessary, and the class will allow you to do your own plotting routines on raw data, but the defaults might complain or call processing routines themselves.
#
# prepare_defaults() generates a standard set of plots in a dictionary called 'plots' whose keys are generally in the format 'x-axis_y-axis' where the axes are taken from the directory dictionary of the dataset. But two line plots are hard coded and only show the y axis.

# %%
plots = pt.Bokeh_Plotting(FEL)
plots.prepare_defaults()
plots.plot_defaults()

# %% [markdown]
# This generates a filename.html file that can be opened in any browser. For large datasets automatic binning will be implemented so that the raw data scatter plots do not fill up memory or make the file unusable. To create custom plots one can call custom_plot. This will overwrite the files generated above, so it is reccomended that file_name be filled in

# %%
plots.custom_plot(x_axis='x', y_axis='y', key='pop', plotter='circle', color='pink',
                  file_name='transverse', text_color='black', Legend='thing', title='Transverse position')
# Out:
# INFO:bokeh.core.state:Session output file '/home/daniel_b/Documents/Summer_project/example.html' already exists, will be overwritten.
# Figure(id='72bd44cd-d183-4574-844a-04636799732d', ...)

# %% [markdown]
# By importing the following modules one can show plots within the notebook, or alternatively through ipython

# %%
from bokeh.plotting import show
from bokeh.io import output_notebook
output_notebook()

show(plots.plots['pop'])
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8899133c-4e80-43d8-b6c5-af782ba44e2f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9548b640-66f8-4e74-919b-848c2dee64d6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("9548b640-66f8-4e74-919b-848c2dee64d6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9548b640-66f8-4e74-919b-848c2dee64d6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9548b640-66f8-4e74-919b-848c2dee64d6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f0636ffd-ac4c-4c75-bac3-b17d496797bc":{"roots":{"references":[{"attributes":{"plot":{"id":"7022613a-5e2f-4a92-94f3-d12e5aa981d1","subtype":"Figure","type":"Plot"}},"id":"1edf9ad5-6ad4-49fe-9b50-e054f1f624b0","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c24ab187-e643-442e-bc1f-d33678c956b5","type":"Circle"},{"attributes":{"below":[{"id":"d9683365-4b95-4aa8-b575-f47411b97180","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"95591c6d-90b1-47c9-a881-9c5c093ffcbd","type":"LinearAxis"}],"renderers":[{"id":"d9683365-4b95-4aa8-b575-f47411b97180","type":"LinearAxis"},{"id":"099c4598-4da5-43d4-bfab-ca158522dcc5","type":"Grid"},{"id":"95591c6d-90b1-47c9-a881-9c5c093ffcbd","type":"LinearAxis"},{"id":"e6e5426e-2e16-4332-b750-9fcd40881100","type":"Grid"},{"id":"13766bfb-9438-4074-a4ef-554531fa17b0","type":"BoxAnnotation"},{"id":"0f5525bf-922f-4282-a8eb-ef80ef39a4c7","type":"Legend"},{"id":"9c3913b1-abb1-4acb-baf9-d63381aa2a59","type":"GlyphRenderer"}],"title":{"id":"a0488695-3d28-4473-bcbf-f509047553b8","type":"Title"},"tool_events":{"id":"cda3bc4f-e7e0-45f9-8070-74ef763c5bd5","type":"ToolEvents"},"toolbar":{"id":"471fefc5-5c4d-4373-b64e-5d320349d1a4","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"d6509021-9bea-4116-931b-881f6d8d1491","type":"DataRange1d"},"y_mapper_type":"auto","y_range":{"id":"c6c292a5-ed9c-4dd4-8b47-a6b6ca2b06bb","type":"DataRange1d"}},"id":"7022613a-5e2f-4a92-94f3-d12e5aa981d1","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"X position ","formatter":{"id":"565cb775-5d8b-4725-a53b-7d9c3608ed5a","type":"BasicTickFormatter"},"plot":{"id":"7022613a-5e2f-4a92-94f3-d12e5aa981d1","subtype":"Figure","type":"Plot"},"ticker":{"id":"948bedac-413a-46cb-998a-ed293e5798df","type":"BasicTicker"}},"id":"d9683365-4b95-4aa8-b575-f47411b97180","type":"LinearAxis"},{"attributes":{"label":{"value":"thing"},"renderers":[{"id":"9c3913b1-abb1-4acb-baf9-d63381aa2a59","type":"GlyphRenderer"}]},"id":"d676c234-8085-4482-9adf-377469afc1f7","type":"LegendItem"},{"attributes":{"items":[{"id":"d676c234-8085-4482-9adf-377469afc1f7","type":"LegendItem"}],"plot":{"id":"7022613a-5e2f-4a92-94f3-d12e5aa981d1","subtype":"Figure","type":"Plot"}},"id":"0f5525bf-922f-4282-a8eb-ef80ef39a4c7","type":"Legend"},{"attributes":{"axis_label":"Y position ","axis_label_text_color":{"value":"black"},"formatter":{"id":"e96c3284-8166-49b9-a793-393e5f4d987a","type":"BasicTickFormatter"},"plot":{"id":"7022613a-5e2f-4a92-94f3-d12e5aa981d1","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5c4d759-73c5-49fe-84a1-e115ca2cd4e6","type":"BasicTicker"}},"id":"95591c6d-90b1-47c9-a881-9c5c093ffcbd","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"pink"},"line_color":{"value":"pink"},"x":{"field":"x"},"y":{"field":"y"}},"id":"86f41654-4879-4180-a507-04eaf5019483","type":"Circle"},{"attributes":{},"id":"e5c4d759-73c5-49fe-84a1-e115ca2cd4e6","type":"BasicTicker"},{"attributes":{},"id":"948bedac-413a-46cb-998a-ed293e5798df","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50000]}}},"id":"17c0b689-9df6-425f-9b3c-0456332ac59d","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"d6509021-9bea-4116-931b-881f6d8d1491","type":"DataRange1d"},{"attributes":{"plot":{"id":"7022613a-5e2f-4a92-94f3-d12e5aa981d1","subtype":"Figure","type":"Plot"}},"id":"be4f6078-ad7a-4a6e-a417-c63b13ed65f0","type":"PanTool"},{"attributes":{},"id":"e96c3284-8166-49b9-a793-393e5f4d987a","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"13766bfb-9438-4074-a4ef-554531fa17b0","type":"BoxAnnotation"},"plot":{"id":"7022613a-5e2f-4a92-94f3-d12e5aa981d1","subtype":"Figure","type":"Plot"}},"id":"9e2bcb37-176f-4e36-a47b-d39c3be3508a","t ...
